# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
plt.plot(data["Age"],data["Overall"],"r.")

# %%
player = data.loc[1000,:]
print(player[2])
plt.plot(player[29:54],"r.")
# Out:
# A. Poli

# %%
plt.plot(data["Age"], data["Value"],"b.")

# %%
data["new_value"] = data["Value"].str[1:].str.replace("M","e6" ).str.replace("K","e3").astype(float)
data["new_wage"] = data["Wage"].str[1:].str.replace("M","e6" ).str.replace("K","e3").astype(float)
data["new_release"] = data["Release Clause"].str[1:].str.replace("M","e6" ).str.replace("K","e3").astype(float)

plt.plot(data["Overall"],data["new_wage"], "g.")

# %%
plt.plot(data["Overall"],data["new_value"], "g.")

# %%
plt.plot(data["Overall"],data["new_release"], "g.")

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(75,90)
ax.plot(data["Overall"],data["Age"],data["new_value"],"b.")
#ax.plot(x_train,z_train,hypothesis(final_a,x_train,z_train,final_b,final_c),"g.")

# %%
data["pot"] = data["Potential"] - data["Overall"]

# %%
plt.plot(data["Age"], data["pot"],"b.")

# %%
data["Nationality"].value_counts().plot(kind="bar",figsize=(30,8))

# %%
a
# Out:
# Nationality
# Afghanistan                4
# Albania                   40
# Algeria                   60
# Andorra                    1
# Angola                    15
# Antigua & Barbuda          4
# Argentina                892
# Armenia                   10
# Australia                234
# Austria                  298
# Azerbaijan                 5
# Barbados                   3
# Belarus                    4
# Belgium                  260
# Belize                     1
# Benin                     15
# Bermuda                    2
# Bolivia                   29
# Bosnia Herzegovina        61
# Botswana                   1
# Brazil                   768
# Bulgaria                  32
# Burkina Faso              16
# Burundi                    3
# Cameroon                  90
# Canada                    64
# Cape Verde                19
# Central African Rep.       3
# Chad                       2
# Chile                    382
#                         ...
# ...
